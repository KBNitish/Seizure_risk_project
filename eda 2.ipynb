# %%
import pandas as pd
import numpy as np
import os
os.environ['MPLBACKEND'] = '' 

import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Sample_synthetic_seizure_data.csv")

df.head()
# Out:
#        id                     created_at  heart_rate  spo2  temperature  \
# 0  100000  2026-09-06 10:00:00.000 +0530        73.3  97.9           30
# 1  100001  2026-09-06 10:00:01.000 +0530        77.3  98.1           30
# 2  100002  2026-09-06 10:00:02.000 +0530        78.4  97.9           30
# 3  100003  2026-09-06 10:00:03.000 +0530        77.3  97.4           30
# 4  100004  2026-09-06 10:00:04.000 +0530        70.9  97.6           30
#
#    humidity  accel_x  accel_y  accel_z  gyro_x  gyro_y  gyro_z  ir_value  \
# 0      51.9   -0.210   -0.025    0.377   1.786   0.624   1.041      2742
# 1      48.5   -0.180    0.172    0.353   1.915   0.886   0.491      2644
# 2      51.0   -0.137    0.002    0.395   0.788  -0.217   0.788      2535
# 3      48.5   -0.207    0.059    0.359   2.655   0.923   1.122      2817
# 4      51.5   -0.220    0.244    0.284   1.121   0.969   1.498      2791
#
#    red_value  finger_detected  seizure
# 0        981             True        0
# 1        934             True        0
# 2        961             True        0
# 3        933             True        0
# 4        959             True        0
